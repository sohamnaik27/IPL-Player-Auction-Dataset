# %% [markdown]
# ## M504 - Individual Final Project (Submission) (Group C)

# %% [markdown]
# ## Submitted by - GH1019876

# %% [markdown]
# ## Submission Date - 24 - March - 2022

# %% [markdown]
# ## IPL Player Auction Dataset - From Start to Now

# %% [markdown]
# <a href="https://www.kaggle.com/datasets/kalilurrahman/ipl-player-auction-dataset-from-start-to-now/code">Dataset Link</a>

# %% [markdown]
# ### Content
# #### 1] Introduction
# #### 2] Objective
# #### 3] Importing Libraries
# #### 4] Loading the DataSet
# #### 5] Data processing
# #### 6] Questions based on data set
# #### 7] Conclusion

# %% [markdown]
# ## Questions
# #### Q1] Display the total number of teams in the dataset
# #### Q2] Display the names of all the players in the dataset
# #### Q3] Most expensive top 10 Players
# #### Q4] Most expensive player each year
# #### Q5] Most expensive player according to their role
# #### Q6] Most expensive player purchased my each team
# #### Q7] Higest spending teams each year.

# %% [markdown]
# ### Introduction
# #### Client Company has provided us with a data set of players of the IPL tournament. They need us to work on the data set and a set of questions which they need us to find answers to. The data set contains different values such as player name, their role, the amount for each player, their team name and the origin of players.

# %% [markdown]
# ### Objectives
# #### The client wants to know the amount which is spent of each players each year and then the amount which has been spent by each team. At the end of the task the client will gather all the data and then analysis it and place some restrictions on each teams so that financial fairplay is maintained.

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Loading Dataset

# %%
ipl_dataset=pd.read_csv("../../datasets/IPLPlayerAuctionData.csv") 
ipl_dataset
# Out:
#                      Player     Role    Amount                         Team  \
# 0               Aaron Finch  Batsman  40000000          Sunrisers Hyderabad
# 1               Aaron Finch  Batsman  32000000               Mumbai Indians
# 2               Aaron Finch  Batsman  10000000                Gujarat Lions
# 3               Aaron Finch  Batsman  62000000              Kings XI Punjab
# 4               Aaron Finch  Batsman  44000000  Royal Challengers Bangalore
# ..                      ...      ...       ...                          ...
# 965  Yuzvendra Singh Chahal   Bowler   1000000  Royal Challengers Bangalore
# 966  Yuzvendra Singh Chahal   Bowler  60000000  Royal Challengers Bangalore
# 967             Zaheer Khan   Bowler  26000000               Mumbai Indians
# 968             Zaheer Khan   Bowler  40000000             Delhi Daredevils
# 969      Zahir Khan Pakteen   Bowler   6000000             Rajasthan Royals
#
#        Year Player Origin
# 0    2014.0      Overseas
# ...

# %%
ipl_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 970 entries, 0 to 969
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Player         970 non-null    object
#  1   Role           970 non-null    object
#  2   Amount         970 non-null    int64
#  3   Team           970 non-null    object
#  4   Year           969 non-null    float64
#  5   Player Origin  970 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 45.6+ KB

# %% [markdown]
# #### Removing the row where year is null

# %%
ipl_dataset.dropna(inplace=True)

# %% [markdown]
# #### Converting the data type of Year's column from float to int

# %%
ipl_dataset.Year = ipl_dataset.Year.apply(int)

# %%
ipl_dataset.head()
# Out:
#         Player     Role    Amount                         Team  Year  \
# 0  Aaron Finch  Batsman  40000000          Sunrisers Hyderabad  2014
# 1  Aaron Finch  Batsman  32000000               Mumbai Indians  2015
# 2  Aaron Finch  Batsman  10000000                Gujarat Lions  2016
# 3  Aaron Finch  Batsman  62000000              Kings XI Punjab  2018
# 4  Aaron Finch  Batsman  44000000  Royal Challengers Bangalore  2020
#
#   Player Origin
# 0      Overseas
# 1      Overseas
# 2      Overseas
# 3      Overseas
# 4      Overseas

# %%
ipl_dataset.tail()
# Out:
#                      Player    Role    Amount                         Team  \
# 965  Yuzvendra Singh Chahal  Bowler   1000000  Royal Challengers Bangalore
# 966  Yuzvendra Singh Chahal  Bowler  60000000  Royal Challengers Bangalore
# 967             Zaheer Khan  Bowler  26000000               Mumbai Indians
# 968             Zaheer Khan  Bowler  40000000             Delhi Daredevils
# 969      Zahir Khan Pakteen  Bowler   6000000             Rajasthan Royals
#
#      Year Player Origin
# 965  2014        Indian
# 966  2018        Indian
# 967  2014        Indian
# 968  2015        Indian
# 969  2018        Indian

# %% [markdown]
# ### Data Preprocessing

# %%
ipl_dataset.isna().sum()
# Out:
# Player           0
# Role             0
# Amount           0
# Team             0
# Year             0
# Player Origin    0
# dtype: int64

# %%
sns.heatmap(ipl_dataset.isnull(),cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
ipl_dataset.Role.unique()
# Out:
# array(['Batsman', 'All-Rounder', 'Bowler', 'Wicket Keeper'], dtype=object)

# %% [markdown]
# #### Q1] Display the total number of teams in the dataset

# %%
print(f"Dataset contains data of Teams")
print(ipl_dataset.Team.unique().size)
ipl_dataset.Team.unique()
# Out:
# Dataset contains data of Teams
# 15
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Kings XI Punjab', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Gujarat Titans', 'Pune Warriors India',
#        'Rajasthan Royals', 'Delhi Daredevils', 'Chennai Super Kings',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Lucknow Super Giants',
#        'Punjab Kings'], dtype=object)

# %% [markdown]
# #### Q2] Display the names of all the players in the dataset

# %%
print('Names of Players in the data set')
print(ipl_dataset.Player.unique().size)
ipl_dataset.Player.unique()
# Out:
# Names of Players in the data set
# 543
# array(['Aaron Finch', 'Abdul Samad', 'Abhijeet Tomar', 'Abhimanyu Mithun',
#        'Abhinav Sadarangani', 'Abhishek Nayar', 'Abhishek Sharma',
#        'Abu Nechim Ahmed', 'Adam Milne', 'Adam Zampa', 'Aditya Garhwal',
#        'Aditya Tare', 'Agnivesh Ayachi', 'Aiden Blizzard',
#        'Aiden Markram', 'Ajantha Mendis', 'Ajinkya Rahane', 'Akash Deep',
#        'Akash Singh', 'Akhil Arvind Herwadkar', 'Akila Dananjaya',
#        'Akila Dhananjaya', 'Akshar Rajesh Patel', 'Akshay Karnewar',
#        'Akshay Wakhare', 'Akshdeep Nath', 'Albie Morkel', 'Alex Carey',
#        'Alex Hales', 'Alzarri Joseph', 'Aman Khan', 'Ambati Rayudu',
#        'Amit Mishra', 'Amit Paunikar', 'Andre Russell', 'Andrew Tye',
#        'Aneeshwar Gautam', 'Angelo Mathews', 'Aniket Choudhary',
#        'Anirudha Ashok Joshi', 'Ankeet Bawane', 'Ankit Nagendra Sharma',
#        'Ankit Sharma', 'Ankit Singh Rajpoot', 'Ankush Bains',
# ...

# %% [markdown]
# #### Q3] Most expensive top 10 Players

# %%
data = ipl_dataset[['Player','Amount','Year']].sort_values("Amount", axis = 0, ascending = False)[:10]
data
# Out:
#                  Player     Amount  Year
# 187  Christopher Morris  162500000  2021
# 960        Yuvraj Singh  160000000  2015
# 632         Pat Cummins  155000000  2020
# 311        Ishan Kishan  152500000  2022
# 455       Kyle Jamieson  150000000  2021
# 137     Benjamin Stokes  145000000  2017
# 280       Glenn Maxwell  142500000  2021
# 222       Deepak Chahar  140000000  2022
# 368     Jhye Richardson  140000000  2021
# 959        Yuvraj Singh  140000000  2014

# %% [markdown]
# #### Q4] Most expensive player each year

# %%
data = []
for i in sorted(ipl_dataset.Year.unique()):
    df = pd.DataFrame(ipl_dataset.groupby('Year').get_group(i))
    df = df[df['Amount'] == df.Amount.max()]
    data.append([i, np.array(df["Player"]), np.array(df["Amount"])[0], np.array(df["Team"])[0]])
data = pd.DataFrame(data, columns=["Year", "Players", "Amount", "Team"])
data
# Out:
#    Year                                Players     Amount  \
# 0  2013                        [Glenn Maxwell]   75000000
# 1  2014                         [Yuvraj Singh]  140000000
# 2  2015                         [Yuvraj Singh]  160000000
# 3  2016                         [Shane Watson]   95000000
# 4  2017                      [Benjamin Stokes]  145000000
# 5  2018                      [Benjamin Stokes]  125000000
# 6  2019  [Jaydev Unadkat, Varun Chakaravarthy]   84000000
# 7  2020                          [Pat Cummins]  155000000
# 8  2021                   [Christopher Morris]  162500000
# 9  2022                         [Ishan Kishan]  152500000
#
#                           Team
# 0               Mumbai Indians
# 1  Royal Challengers Bangalore
# 2             Delhi Daredevils
# 3  Royal Challengers Bangalore
# 4       Rising Pune Supergiant
# 5             Rajasthan Royals
# 6             Rajasthan Royals
# 7        Kolkata Knight Riders
# 8             Rajasthan Royals
# ...

# %% [markdown]
# #### Q5] Most expensive player according to their role

# %%
data = []
for i in sorted(ipl_dataset.Role.unique()):
    df = pd.DataFrame(ipl_dataset.groupby('Role').get_group(i))
    df = df[df['Amount'] == df.Amount.max()]
    data.append([i, np.array(df["Player"]), np.array(df["Amount"])[0], np.array(df["Team"])[0]])
data = pd.DataFrame(data, columns=["Role", "Player", "Amount", "Team"])
data
# Out:
#             Role                            Player     Amount  \
# 0    All-Rounder              [Christopher Morris]  162500000
# 1        Batsman                    [Yuvraj Singh]  160000000
# 2         Bowler  [Deepak Chahar, Jhye Richardson]  140000000
# 3  Wicket Keeper                    [Ishan Kishan]  152500000
#
#                   Team
# 0     Rajasthan Royals
# 1     Delhi Daredevils
# 2  Chennai Super Kings
# 3       Mumbai Indians

# %% [markdown]
# #### Q6] Most expensive player purchased my each team

# %%
data = []
for i in sorted(ipl_dataset.Team.unique()):
    df = pd.DataFrame(ipl_dataset.groupby('Team').get_group(i))
    df = df[df['Amount'] == df.Amount.max()]
    data.append([i, np.array(df["Player"]), np.array(df["Amount"])[0], np.array(df["Team"])[0]])
data = pd.DataFrame(data, columns=["Role", "Player", "Amount", "Team"])
data
# Out:
#                            Role                Player     Amount  \
# 0           Chennai Super Kings       [Deepak Chahar]  140000000
# 1                Delhi Capitals      [Shardul Thakur]  107500000
# 2              Delhi Daredevils        [Yuvraj Singh]  160000000
# 3                 Gujarat Lions       [Praveen Kumar]   35000000
# 4                Gujarat Titans     [Lockie Ferguson]  100000000
# 5               Kings XI Punjab            [KL Rahul]  110000000
# 6         Kolkata Knight Riders         [Pat Cummins]  155000000
# 7          Lucknow Super Giants          [Avesh Khan]  100000000
# 8                Mumbai Indians        [Ishan Kishan]  152500000
# 9           Pune Warriors India      [Ajantha Mendis]   54375000
# 10                 Punjab Kings     [Jhye Richardson]  140000000
# 11             Rajasthan Royals  [Christopher Morris]  162500000
# 12       Rising Pune Supergiant     [Benjamin Stokes]  145000000
# ...

# %% [markdown]
# #### Q7] Higest spending teams each year.

# %%
data = []
for i in sorted(ipl_dataset.Year.unique()):
    df = pd.DataFrame(ipl_dataset.groupby('Year').get_group(i))
    df = df[df['Amount'] == df.Amount.max()]
    data.append([i, np.array(df["Amount"])[0], np.array(df["Team"])[0]])
data = pd.DataFrame(data, columns=["Year", "Amount", "Team"])
data
# Out:
#    Year     Amount                         Team
# 0  2013   75000000               Mumbai Indians
# 1  2014  140000000  Royal Challengers Bangalore
# 2  2015  160000000             Delhi Daredevils
# 3  2016   95000000  Royal Challengers Bangalore
# 4  2017  145000000       Rising Pune Supergiant
# 5  2018  125000000             Rajasthan Royals
# 6  2019   84000000             Rajasthan Royals
# 7  2020  155000000        Kolkata Knight Riders
# 8  2021  162500000             Rajasthan Royals
# 9  2022  152500000               Mumbai Indians

# %% [markdown]
# ### Conclusion
# #### After analysing the IPL data set we have received the following data:-
# #### 1] We have noticed that the amount difference between the higest paid player and the least paid play is a lot and most of the higher paid payers are overseas players.
# #### 2] We also noticed that the amount of money spent on All-Rounders is more as compared to that of Batsman and Bowlers.
# #### 3] There are biggere teams such as Mumbai Indians and Royal Challengers Banglore who spend more money that teams such as Kolkata Knighr Riders.
